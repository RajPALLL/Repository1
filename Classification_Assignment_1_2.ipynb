# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9e6a2481-ae69-45f5-adc8-45582b6d6992" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e6a2481-ae69-45f5-adc8-45582b6d6992">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nba_data.csv to nba_data.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd 
df = pd.read_csv("nba_data.csv")
df.head()
# Out:
#               Name  GP   MIN  PTS  FGS  FGA  3PM  3PA  FTM  FTA  OREB  DREB  \
# 0   Brandon Ingram  36  27.4  7.4  2.6  7.6  0.5  2.1  1.6  2.3   0.7   3.4
# 1  Andrew Harrison  35  26.9  7.2  2.0  6.7  0.7  2.8  2.6  3.4   0.5   2.0
# 2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  0.4  1.7  0.9  1.3   0.5   1.7
# 3      Malik Sealy  58  11.6  5.7  2.3  5.5  0.1  0.5  0.9  1.3   1.0   0.9
# 4      Matt Geiger  48  11.5  4.5  1.6  3.0  0.0  0.1  1.3  1.9   1.0   1.5
#
#    AST  STL  BLK  TOV  5Yrs
# 0  1.9  0.4  0.4  1.3     0
# 1  3.7  1.1  0.5  1.6     0
# 2  1.0  0.5  0.3  1.0     0
# 3  0.8  0.6  0.1  1.0     1
# 4  0.3  0.3  0.4  0.8     1

# %%
col_count = df.shape[1]
print("number of Variables:",col_count)
row_count = len(df) 
print("number of Instances:",row_count)
total = df.size
print("total size of rows and collums:", total)
df.shape
# Out:
# number of Variables: 17
# number of Instances: 1308
# total size of rows and collums: 22236
# (1308, 17)

# %%
first_row = df.head(1)
print(first_row)
# Out:
#              Name  GP   MIN  PTS  FGS  FGA  3PM  3PA  FTM  FTA  OREB  DREB  \
# 0  Brandon Ingram  36  27.4  7.4  2.6  7.6  0.5  2.1  1.6  2.3   0.7   3.4
#
#    AST  STL  BLK  TOV  5Yrs
# 0  1.9  0.4  0.4  1.3     0

# %%
import numpy as np
Standard_deviation= np.std(df)
Mean= np.mean(df)

print(Standard_deviation)
print(Mean)
# df.mean
# df.std
# Out:
# GP      17.400339
# MIN      8.283195
# PTS      4.330093
# FGS      1.672070
# FGA      3.570773
# 3PM      0.385665
# 3PA      1.066023
# FTM      0.980312
# FTA      1.315252
# OREB     0.774356
# DREB     1.355824
# AST      1.467643
# STL      0.409548
# BLK      0.430945
# TOV      0.719702
# 5Yrs     0.484418
# dtype: float64
# GP      60.344801
# MIN     17.605352
# PTS      6.785321
# FGS      2.622630
# FGA      5.871865
# 3PM      0.249083
# 3PA      0.781422
# FTM      1.292890
# FTA      1.815291
# OREB     1.008639
# DREB     2.023930
# AST      1.543807
# STL      0.616820
# BLK      0.369495
# TOV      1.189144
# 5Yrs     0.623853
# dtype: float64
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3579: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
x = df.iloc[:,1:15] #independent Variable
x
y = df.iloc[:,16]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 1303    0
# 1304    1
# 1305    0
# 1306    1
# 1307    1
# Name: 5Yrs, Length: 1308, dtype: int64

# %%
#Look at data types of the variables. Are there any categorical variable you need to encode? Execute necessary transformations. Drop some columns if necessary, when recommended 
#in your individual variant. 
x.dtypes
# Out:
# GP        int64
# MIN     float64
# PTS     float64
# FGS     float64
# FGA     float64
# 3PM     float64
# 3PA     float64
# FTM     float64
# FTA     float64
# OREB    float64
# DREB    float64
# AST     float64
# STL     float64
# BLK     float64
# dtype: object

# %%
#Are there any Nan values? Try different filling of them (mean, median).
print(df.isnull().sum())
# Out:
# (1308, 17)

# %%
df.isnull()

# import modelling and metrics for decision trees from sklearn
from sklearn.model_selection import train_test_split


# define target
y = df['5Yrs']

# create an array of all the input features and define the X
all_features=['GP', 'MIN', 'PTS', 'FGS', 'FGA', '3PM', '3PA', 'FTM', 'FTA', 'OREB', 'DREB', 'AST', 'STL', 'BLK', 'TOV']
X_all=df[all_features]

# perform the training-testing split
X_all_train, X_all_test, y_all_train, y_all_test = train_test_split(X_all, y, train_size=0.8, random_state=1)

# display the length of the lists to check 
print("Size of X_all_train: ",X_all_train.shape)
print("Length of y_all_train: ",len(y_all_train))
print("Size of X_all_test: ",X_all_test.shape)
print("Length of y_all_test: ",len(y_all_test))
# Out:
# Size of X_all_train:  (1046, 15)
# Length of y_all_train:  1046
# Size of X_all_test:  (262, 15)
# Length of y_all_test:  262

# %%
df.isnull() #to check any null value is df
df.fillna(df.mean()) #Impute / Replace Missing Values with Mean
df.fillna(df.median()) #Impute / Replace Missing Values with Median
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                  Name  GP   MIN  PTS  FGS  FGA  3PM  3PA  FTM  FTA  OREB  \
# 0      Brandon Ingram  36  27.4  7.4  2.6  7.6  0.5  2.1  1.6  2.3   0.7
# 1     Andrew Harrison  35  26.9  7.2  2.0  6.7  0.7  2.8  2.6  3.4   0.5
# 2      JaKarr Sampson  74  15.3  5.2  2.0  4.7  0.4  1.7  0.9  1.3   0.5
# ...

# %%
#Check the dependences between each of the independent variable and the target variable 
#and among the independent variables. Output correlation table and corresponding 
#headmap results. 
#df
df[df.columns[1:]].corr()['5Yrs'][:]
# Out:
# GP      0.405857
# MIN     0.323363
# PTS     0.320262
# FGS     0.322085
# FGA     0.295804
# 3PM     0.034574
# 3PA     0.015337
# FTM     0.301543
# FTA     0.301935
# OREB    0.297874
# DREB    0.289467
# AST     0.175555
# STL     0.233433
# BLK     0.214945
# TOV     0.277531
# 5Yrs    1.000000
# Name: 5Yrs, dtype: float64

# %%
#Build 2D plots of dependences between each pair of the variables. Which conclusion can you make?
# Seaborn visualization library
import seaborn as sns
# Create the default pairplot
sns.pairplot(x)

# %%
#Classification Task 2 Task 2 “Data Analysis”

# %%
# Python code explaining How to
# perform Feature Scaling
   
import numpy as np
import matplotlib.pyplot as plt
  
# Sklearn library 
from sklearn import preprocessing
  
   
  
# here Features - Age and Salary columns 
# are taken using slicing
# to handle values with varying magnitude
x = df.iloc[:, 1:15].values
print ("\nOriginal data values : \n",  x)
  
  
  
from sklearn import preprocessing
  
""" MIN MAX SCALER """
  
min_max_scaler = preprocessing.MinMaxScaler(feature_range =(0, 1))
# Scaled feature

x_after_min_max_scaler = min_max_scaler.fit_transform(x)
  
print ("\nAfter min max Scaling : \n", x_after_min_max_scaler)
  
  
""" Standardisation """
  
Standardisation = preprocessing.StandardScaler()
  
# Scaled feature
x_after_Standardisation = Standardisation.fit_transform(x)
  
print ("\nAfter Standardisation : \n", x_after_Standardisation)
# Out:
# Original data values :
#  [[36.  27.4  7.4 ...  1.9  0.4  0.4]
#  [35.  26.9  7.2 ...  3.7  1.1  0.5]
#  [74.  15.3  5.2 ...  1.   0.5  0.3]
#  ...
#  [43.  12.1  5.4 ...  0.3  0.3  0.4]
#  [52.  12.   4.5 ...  2.2  0.4  0.1]
#  [47.  11.7  4.4 ...  1.4  0.7  0.1]]
#
# After min max Scaling :
#  [[0.35211268 0.64285714 0.24363636 ... 0.17924528 0.16       0.1025641 ]
#  [0.33802817 0.62962963 0.23636364 ... 0.3490566  0.44       0.12820513]
#  [0.88732394 0.32275132 0.16363636 ... 0.09433962 0.2        0.07692308]
#  ...
#  [0.45070423 0.23809524 0.17090909 ... 0.02830189 0.12       0.1025641 ]
#  [0.57746479 0.23544974 0.13818182 ... 0.20754717 0.16       0.02564103]
#  [0.50704225 0.22751323 0.13454545 ... 0.13207547 0.28       0.02564103]]
#
# After Standardisation :
#  [[-1.39909928  1.18247228  0.14195512 ...  0.2426971  -0.52941223
#    0.07078541]
#  [-1.45656942  1.1221091   0.09576674 ...  1.46915356  1.1797903
#    0.30283383]
# ...

# %%
#Split Data in testing and Training Dataset

from sklearn.model_selection import train_test_split

# Define the input features and target
input_features = ['GP', 'MIN', 'PTS', 'FGS', 'FGA', '3PM', '3PA', 'FTM', 'FTA', 'OREB', 'DREB', 'AST', 'STL', 'BLK', 'TOV']
target = '5Yrs'


# Separate the input dataset from the target values
X = df[input_features]
y = df[target]


# Perform the train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, random_state=2)

print("Size of X_train: ",X_train.shape)
print("Length of y_train: ",len(y_train))
print("Size of X_test: ",X_test.shape)
print("Length of y_test: ",len(y_test))
#X_train.head
X_test.shape
#X_test.head
# Out:
# Size of X_train:  (1177, 15)
# Length of y_train:  1177
# Size of X_test:  (131, 15)
# Length of y_test:  131
# (131, 15)

# %%
#Preliminary analysis: For each model: train with training set and output the regression 
#score (R2) of the model using training set. Now test your model with a testset and output the 
#regression score (R2). Compare R2 inside one model for training and testing sets. Calculate 
#other metrics MSE, RMSE, MAE, mentioned in the corresponding lecture. Compare the same 
#characteristics calculated with training and test sets. Output the coefficients of the linear 
#regression model. Which variables have the biggest influence on the output (dependent 
#variables)? Write the conclusions in the notebook as a text field. 

#Task 2 Part 3

import numpy as np
from sklearn.metrics import r2_score
np.random.seed(2)
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn.metrics as metrics
from sklearn.metrics import mean_absolute_error, r2_score , mean_squared_error
from math import sqrt
# define target
target = ['5Yrs']


# create an array of all the input features and define the X
all_features=['GP', 'MIN', 'PTS', 'FGS', 'FGA', '3PM', '3PA', 'FTM', 'FTA', 'OREB', 'DREB', 'AST', 'STL', 'BLK', 'TOV']
X_all=df[all_features]

# Separate the input dataset from the target values
X = df[all_features]
y = df[target]


# Perform the train/test split
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.9, random_state=2)
model = LinearRegression()
model.fit(x_train , y_train)
y_pred = model.predict(x_test)


#for Linear Model
print("For Linear Regression")
lm.fit(X_train,y_train)
predictions_lm=lm.predict(X_test)
print(predictions_lm)
# print('MAE For Linear Model:', metrics.mean_absolute_error(y_test, predictions))
# print('MSE For Linear Model:', metrics.mean_squared_error(y_test, predictions))
# print('RMSE For Linear Model:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

#for  Decision Tree Model
print("• Support vector machine regression ") 
#for Classification
#clf_gini.fit(X_train, y_train)
#predictions_DT=clf_gini.predict(X_test)
#print(predictions_DT)

regressor_DT = DecisionTreeRegressor(random_state = 0) 
  
# fit the regressor with X and Y data
regressor_DT.fit(X_train, y_train)
predictions_DT = regressor_DT.predict(X_test)
print(predictions_DT)

#for Support Vector 
#from sklearn.svm import SVR
print("• Support vector machine regression ")
regr = svm.SVR()
regr.fit(X_train, y_train)
#for Classification.
#clf.fit(X_train, y_train)
predictions_SVR = regr.predict(X_test)
print(predictions_SVR)

#KNN K nearest Neghbour:
print("KNN")
neigh = KNeighborsRegressor(n_neighbors=15)
neigh.fit(X_train, y_train)
predictions_KNN = neigh.predict(X_test)
print(predictions_KNN)





mse = mean_squared_error(y_pred , y_test)

mae = mean_absolute_error(y_pred,y_test)
rmse = sqrt(mean_squared_error(y_pred,y_test))
#rmse2=sqrt(((y_pred - y_test) ** 2).mean())
score = r2_score( y_test, y_pred)

print("MSE : ",mse)
print("Score | R2 : ",score)
print("MAE : ",mse)
print("RMSE : ",rmse)
#print("RMSE2",rmse2)
model.intercept_
model.coef_
# Out:
# For Linear Regression
# [[0.52698518]
#  [0.64148013]
#  [0.59962385]
#  [0.52924315]
#  [0.60107463]
#  [0.60836118]
#  [0.63680885]
#  [0.69860504]
#  [0.61967227]
#  [0.63522717]
#  [0.65118908]
#  [0.63663927]
#  [0.67357298]
#  [0.62663016]
#  [0.66658423]
#  [0.57798053]
#  [0.66081218]
#  [0.62900647]
#  [0.62107222]
#  [0.66811789]
#  [0.75115254]
#  [0.67648939]
#  [0.6536622 ]
#  [0.62966393]
#  [0.5823839 ]
#  [0.62039357]
#  [0.63272636]
#  [0.52489442]
#  [0.62210621]
#  [0.62880936]
#  [0.59878797]
#  [0.60969179]
#  [0.64891169]
#  [0.67446621]
#  [0.62427528]
#  [0.59039022]
#  [0.73264419]
#  [0.56793515]
#  [0.60926129]
#  [0.66416327]
#  [0.64594748]
#  [0.71283802]
#  [0.58896858]
#  [0.59157479]
#  [0.67245547]
#  [0.61386181]
#  [0.72068086]
#  [0.64366544]
#  [0.48684481]
#  [0.74133042]
#  [0.63331209]
#  [0.64842798]
#  [0.64924815]
#  [0.59780459]
#  [0.67147555]
#  [0.61528415]
#  [0.6234882 ]
#  [0.65142259]
#  [0.60607614]
#  [0.54297429]
#  [0.59091366]
# ...

# %% [markdown]
# from the above statement the conclusion statement is that

# %%
#Recalculate the results of Task 2 (use the same random_state as for Standard Scaler by 
#splitting) with MinMaxScaler and compare the results based on metric R2. Use the Scaler, 
#which gives the best results for the next Tasks.

# Python code explaining How to
# perform Feature Scaling
   
import numpy as np
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
# Sklearn library 
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
# Separate the input dataset from the target values
X = df[input_features]
y = df[target]


# Perform the train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, random_state=2)


   
  
# here Features - Age and Salary columns 
# are taken using slicing
# to handle values with varying magnitude
# x = X.iloc[:, 1:15].values
# print ("\nOriginal data values : \n",  x)

   
# """ MIN MAX SCALER """
  

MinMaxscaler = MinMaxScaler().fit(X_train)
x_after_min_max_scaler = MinMaxscaler.fit_transform(X_train)

print()
test_MMsc = MinMaxscaler.transform(X_test) 

print ("\nAfter min max Scaling : \n", x_after_min_max_scaler)
  
  
# """ Standardisation """
  
# Standardisation = preprocessing.StandardScaler()
  
# # Scaled feature
# x_after_Standardisation = Standardisation.fit_transform(x)

scaler = StandardScaler().fit(X_train)
train_sc = scaler.transform(X_train)
#print(train_sc)

test_sc = scaler.transform(X_test) 
#print(test_sc)
print ("\nscaler : \n", train_sc)

#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, random_state=2)

#Regression Metrics

#kfold = model_selection.KFold(n_splits=10, random_state=7, shuffle=True)
model = LinearRegression()
scoring = 'r2'
results = model_selection.cross_val_score(model, train_sc, x_after_min_max_scaler, scoring=scoring)
print("R^2: %.3f (%.3f)" % (results.mean(), results.std()))
# Out:
# After min max Scaling :
#  [[0.47887324 0.16304348 0.09322034 ... 0.16       0.02564103 0.09302326]
#  [0.98591549 0.48641304 0.45762712 ... 0.32       0.1025641  0.37209302]
#  [0.5915493  0.08967391 0.05508475 ... 0.16       0.         0.1627907 ]
#  ...
#  [0.97183099 0.29076087 0.16101695 ... 0.08       0.38461538 0.34883721]
#  [0.98591549 0.50815217 0.45762712 ... 0.52       0.07692308 0.46511628]
#  [0.45070423 0.13315217 0.08474576 ... 0.28       0.         0.18604651]]
#
# scaler :
#  [[-0.86798068 -0.90023457 -0.89863131 ... -0.51971003 -0.6189399
#   -0.95334299]
#  [ 1.18987952  0.53896319  1.10876742 ...  0.46412383  0.06637737
#    0.70756936]
#  [-0.41067842 -1.22677524 -1.10870792 ... -0.51971003 -0.84737899
#   -0.5381149 ]
#  ...
#  [ 1.13271674 -0.33181193 -0.52516178 ... -1.01162696  2.57920737
#    0.56916   ]
#  [ 1.18987952  0.63571598  1.10876742 ...  1.69391616 -0.16206172
#    1.26120681]
#  [-0.98230625 -1.03326966 -0.945315   ...  0.21816537 -0.84737899
# ...

# %%
from scipy.sparse.construct import rand
#Task 3 “Cross validation"
import numpy as np 
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
import sklearn.svm
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn import linear_model, tree, ensemble

input_features = ['GP', 'MIN', 'PTS', 'FGS', 'FGA', '3PM', '3PA', 'FTM', 'FTA', 'OREB', 'DREB', 'AST', 'STL', 'BLK', 'TOV']
target = '5Yrs'

# Separate the input dataset from the target values
X = df[input_features]
y = df[target]



#cv = KFold(n_splits= 5, shuffle=False, random_state= none )
# # Perform the train/test split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
# cv = KFold(n_splits=5, random_state=1, shuffle=True)

x_CV = train_test_split(X_train, y_train, train_size=0.5)



#Linear Model
#model = LinearRegression()
print("Linear Regerission")
LRCV = LinearRegression()
LRCV.fit(X_train,y_train)
pred = LRCV.predict(X_test)
acc = accuracy_score(y_test,np.round(abs(pred)), normalize= True)
#print('\nCV accuracy for k = %d is %d%%' % (i, acc))
print(acc)    


#DT Tree 
print("Decision Tree Regressor")
DTR =tree.DecisionTreeRegressor()
DTR.fit(X_train,y_train)
pred = DTR.predict(X_test)
acc = accuracy_score(y_test,np.round(abs(pred)), normalize= True)
#print('\nCV accuracy for k = %d is %d%%' % (i, acc))
print(acc)    


#Svm

print("SVM Regression CrossValidation")
#accuracy_score(y_true, np.round(abs(y_pred)), normalize=False) 
SVM_model = sklearn.svm.SVR()
SVM_model.fit(X_train,y_train)
pred = SVM_model.predict(X_test)
acc = accuracy_score(y_test,np.round(abs(pred)), normalize= True)
#print('\nCV accuracy for k = %d is %d%%' % (i, acc))
print(acc)    


print("KNN CrossValidation")
#accuracy_score(y_true, np.round(abs(y_pred)), normalize=False) 
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
acc = accuracy_score(y_test,np.round(abs(pred)), normalize= True)
#print('\nCV accuracy for k = %d is %d%%' % (i, acc))
print(acc)    

# #logesticRegression 
# lr = LogisticRegression()
# lr.fit(X_train, y_train)
# lr.score(X_test, y_test)


# #RFR
# RF = RandomForestRegressor()
# RF.fit(X_train, y_train)
# RF.score(X_test, y_test)
# Out:
# Linear Regerission
# 0.7557251908396947
# Decision Tree Regressor
# 0.6183206106870229
# SVM Regression CrossValidation
# 0.7404580152671756
# KNN CrossValidation
# 0.6183206106870229
